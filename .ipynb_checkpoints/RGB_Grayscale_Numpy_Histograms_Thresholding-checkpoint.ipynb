# %% [markdown]
# # Datacamp Image Processing

# %% [markdown]
# ### Kadriye Tuba Turkcan Karaca

# %% [markdown]
# ## RGB vs Grayscale

# %%
from skimage import color
import matplotlib.pyplot as plt
#import data module
from skimage import data
import numpy as np

# %%
def show_image(image, title = 'Image', cmap_type = 'gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
coffee_image = data.coffee()
coins_image = data.coins()

# %%
grayscale = color.rgb2gray(coffee_image)
rgb = color.gray2rgb(grayscale)

# %%
show_image(coffee_image,'Coffee')

# %%
show_image(rgb, 'gray scale coffee')

# %% [markdown]
# ### RGB to grayscale
# Load an image from scikit-image module data and make it grayscale, then compare both of them in the output.

# %%
# Load the rocket image
rocket = data.rocket()

# Convert the image to grayscale
gray_scaled_rocket = color.rgb2gray(rocket)

# Show the original image
show_image(rocket, 'Original RGB image')

# Show the grayscale image
show_image(gray_scaled_rocket, 'Grayscale image')

# %% [markdown]
# ### Flipping out
# Flip the image horizontally and vertically. Then display the image using the show_image() function.

# %%
# Flip the image vertically
flipped_rocket = np.flipud(rocket)

# %%
show_image(flipped_rocket, "Flipped Rocket")

# %%
# Flip the previous image horizontally
rocket_horizontal_flip = np.fliplr(flipped_rocket)

# %%
show_image(rocket_horizontal_flip, "Horizontal Rocket Flip")

# %% [markdown]
# # Images as NdArrays

# %%
#loading image using matplotlib
image = plt.imread('woman_smiling.jpg')
type(image)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Colors with Numpy

# %%
#Obtaining the red values of the image
red = image[:,:,0]
red
# Out:
# array([[ 52,  51,  51, ..., 128, 128, 124],
#        [ 48,  50,  50, ..., 132, 128, 126],
#        [ 50,  52,  51, ..., 129, 121, 120],
#        ...,
#        [  3,   3,   2, ...,  57,  81,  99],
#        [ 12,  11,  11, ...,  63,  84, 106],
#        [ 22,  20,  20, ...,  50,  69,  94]], dtype=uint8)

# %%
#Obtaining the green values of the image
green = image[:,:,1]
#Obtaining the blue values of the image
blue = image[:,:,2]

# %%
plt.imshow(image) #cmap = 'gray'
plt.title('Original')
plt.axis('off')
plt.show()

# %%
plt.imshow(red) #cmap = 'gray'
plt.title('Red')
plt.axis('off')
plt.show()

# %%
plt.imshow(green) #cmap = 'gray'
plt.title('Green')
plt.axis('off')
plt.show()

# %%
plt.imshow(blue) #cmap = 'gray'
plt.title('Blue')
plt.axis('off')
plt.show()

# %%
#Accesing the shape of the image
image.shape
# Out:
# (256, 256, 3)

# %%
image.size
# Out:
# 196608

# %% [markdown]
# ## Histograms
#
# Use hist() to display the 256 different intensities of the red color. And ravel() to make these color values an array of one flat dimension.

# %%
# Obtain the red histogram
plt.hist(red.ravel(),bins=256)
plt.show()

# %% [markdown]
# ## Global Thresholding

# %%
from skimage.filters import threshold_otsu

# %%
chess_image = plt.imread('chess_pieces_image.jpeg')

# %%
show_image(chess_image, 'original image')

# %%
# Make the image grayscale using rgb2gray
chess_pieces_image_gray = color.rgb2gray(chess_image)

# Obtain the optimal threshold value with otsu
thresh = threshold_otsu(chess_pieces_image_gray)

# Apply thresholding to the image
binary = chess_pieces_image_gray > thresh

# Show the image
show_image(binary, 'Binary image')

# %% [markdown]
# # Local Thresholding
# ### Uneven background
# Sometimes, it isn't that obvious to identify the background. If the image background is relatively uniform, then we can use a global threshold value, using threshold_otsu(). However, if there's uneven background illumination, adaptive thresholding threshold_local() (a.k.a. local thresholding) may produce better results.
#
# Now, we will compare both types of thresholding methods (global and local), to find the optimal way to obtain the binary image we need.

# %%
page_image = data.page()

# %%
#page_image = plt.imread('page_image.png')
show_image(page_image, 'original')

# %%
# Import the otsu threshold function
from skimage.filters import threshold_otsu

# Obtain the optimal otsu global thresh value
global_thresh = threshold_otsu(page_image)

# Obtain the binary image by applying global thresholding
binary_global = page_image > global_thresh

# Show the binary image obtained
show_image(binary_global, 'Global thresholding')

# %%
# Import the local threshold function
from skimage.filters import threshold_local

# Set the block size to 35
block_size = 35

# Obtain the optimal local thresholding
local_thresh = threshold_local(page_image, block_size, offset=10)

# Obtain the binary image by applying local thresholding
binary_local = page_image > local_thresh

# Show the binary image
show_image(binary_local, 'Local thresholding')

# %% [markdown]
# ## Edge detection
# Detect edges in an image by applying the Sobel filter.
#
# Soap pills of heart and rectangle shapes in blue background
# Image preloaded as soaps_image.
# Theshow_image() function has been already loaded for you.
#
# Let's see if it spots all the figures in the image.

# %% [markdown]
# ![image.png](attachment:2382181d-bd12-4c0e-9723-71b9242b2d64.png)

# %%
# Import the color module
from skimage import color
# Import the filters module and sobel function
from skimage.filters import sobel

# %%
# !pip3 install pooch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pooch
#   Using cached pooch-1.6.0-py3-none-any.whl (56 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from pooch) (21.3)
# Requirement already satisfied: requests>=2.19.0 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from pooch) (2.28.1)
# Collecting appdirs>=1.3.0
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from packaging>=20.0->pooch) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from requests>=2.19.0->pooch) (1.26.12)
# Installing collected packages: appdirs, pooch
# Successfully installed appdirs-1.4.4 pooch-1.6.0

# %%
data.coins()
# Out:
# array([[ 47, 123, 133, ...,  14,   3,  12],
#        [ 93, 144, 145, ...,  12,   7,   7],
#        [126, 147, 143, ...,   2,  13,   3],
#        ...,
#        [ 81,  79,  74, ...,   6,   4,   7],
#        [ 88,  82,  74, ...,   5,   7,   8],
#        [ 91,  79,  68, ...,   4,  10,   7]], dtype=uint8)

# %%
coins_image = data.coins()

# %%
#!pip3 install scikit-image
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-image
#   Downloading scikit_image-0.19.3-cp39-cp39-macosx_12_0_arm64.whl (12.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 43.0 MB/s eta 0:00:0000:0100:01
# Collecting imageio>=2.4.1
#   Downloading imageio-2.22.4-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 51.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy>=1.17.0 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from scikit-image) (1.23.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from scikit-image) (1.9.1)
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.3/210.3 kB 11.1 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp39-cp39-macosx_11_0_arm64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 44.5 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from scikit-image) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from scikit-image) (21.3)
# Collecting networkx>=2.2
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 31.7 MB/s eta 0:00:0000:01
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/tuba/Library/Python/3.9/lib/python/site-packages (from packaging>=20.0->scikit-image) (3.0.9)
# Installing collected packages: tifffile, PyWavelets, networkx, imageio, scikit-image
#   WARNING: The scripts lsm2bin, tiff2fsspec, tiffcomment and tifffile are installed in '/Users/tuba/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts imageio_download_bin and imageio_remove_bin are installed in '/Users/tuba/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script skivi is installed in '/Users/tuba/Library/Python/3.9/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed PyWavelets-1.4.1 imageio-2.22.4 networkx-2.8.8 scikit-image-0.19.3 tifffile-2022.10.10

# %%
# Make the image grayscale
soaps_image_gray = color.rgb2gray(coins_image)
soaps_image_gray
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [19], line 2
#       1 # Make the image grayscale
# ----> 2 soaps_image_gray = color.rgb2gray(coins_image)
#       3 soaps_image_gray
#
# File ~/Library/Python/3.9/lib/python/site-packages/skimage/_shared/utils.py:394, in channel_as_last_axis.__call__.<locals>.fixed_func(*args, **kwargs)
#     391 channel_axis = kwargs.get('channel_axis', None)
#     393 if channel_axis is None:
# --> 394     return func(*args, **kwargs)
#     396 # TODO: convert scalars to a tuple in anticipation of eventually
#     397 #       supporting a tuple of channel axes. Right now, only an
#     398 #       integer or a single-element tuple is supported, though.
#     399 if np.isscalar(channel_axis):
#
# File ~/Library/Python/3.9/lib/python/site-packages/skimage/color/colorconv.py:875, in rgb2gray(rgb, channel_axis)
#     834 @channel_as_last_axis(multichannel_output=False)
#     835 def rgb2gray(rgb, *, channel_axis=-1):
#     836     """Compute luminance of an RGB image.
#     837
#     838     Parameters
#    (...)
#     873     >>> img_gray = rgb2gray(img)
#     874     """
# --> 875     rgb = _prepare_colorarray(rgb)
#     876     coeffs = np.array([0.2125, 0.7154, 0.0721], dtype=rgb.dtype)
#     877     return rgb @ coeffs
#
# File ~/Library/Python/3.9/lib/python/site-packages/skimage/color/colorconv.py:140, in _prepare_colorarray(arr, force_copy, channel_axis)
#     137 if arr.shape[channel_axis] != 3:
#     138     msg = (f'the input array must have size 3 along `channel_axis`, '
#     139            f'got {arr.shape}')
# --> 140     raise ValueError(msg)
#     142 float_dtype = _supported_float_type(arr.dtype)
#     143 if float_dtype == np.float32:
#
# ValueError: the input array must have size 3 along `channel_axis`, got (303, 384)

# %%
# Apply edge detection filter
edge_sobel = sobel(soaps_image_gray)

# Show original and resulting image to compare
show_image(soaps_image, "Original")
show_image(edge_sobel, "Edges with Sobel")
